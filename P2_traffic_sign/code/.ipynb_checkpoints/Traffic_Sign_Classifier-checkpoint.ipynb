# %%
from LeNet import LeNet
from traffic_sign_classifier import Pipeline
from utils import DataSetTools, TrainMonitorTools
from keras.utils import np_utils # utilities for one-hot encoding of ground truth values
import glob
from keras.models import load_model
import cv2
import numpy as np
from keras.callbacks import EarlyStopping, ModelCheckpoint

NumEpochs = 20 # train for 20 epochs
Patience = 5 # early stop training if evaluation performance is not increasing after 5 epochs

data_dir = "../data/"
visualize_dir =  data_dir+'visualize/'
test_data_dir = data_dir + 'testImg/'
model_path = data_dir+'model/trafficSign_model.h5'
test_labels = [13, 3, 14, 27, 40]
traffic_sign_pipeline = Pipeline(data_dir, visualize_dir, train_model_path= model_path, test_model_path= model_path)
# Out:
# /Users/jinzhu/anaconda/envs/carnd-term1/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
print("Step 1: Dataset Summary & Exploration")
traffic_sign_pipeline.load_explore_dataset()
# Out:
# Step 1: Dataset Summary & Exploration
# load trianing and validation data
# Number of training examples = 34799
# Number of testing examples = 12630
# Image data shape = (32, 32, 3)
# Number of classes = 43
# visualize before data augmentation on training data
# visualize training data distribution over class
# image shape: img_width = 32, img_height = 32, img_channels = 3

# %%
print("Step 2: Build network")
traffic_sign_pipeline.buildNetwork()
# Out:
# Step 2: Build network
# model summary
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 6)         456
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               51328
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                10836
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                3655
# _________________________________________________________________
# activation_1 (Activation)    (None, 43)                0
# =================================================================
# Total params: 68,691
# Trainable params: 68,691
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
print("Step 3: Train network")
traffic_sign_pipeline.train(numEpochs=NumEpochs)
# Out:
# Step 3: Train network
# train process tool
# Epoch 1/20
# 272/272 [==============================] - 26s 97ms/step - loss: 2.6335 - acc: 0.3303 - val_loss: 1.3957 - val_acc: 0.6388
# Epoch 2/20
# 272/272 [==============================] - 26s 97ms/step - loss: 0.9655 - acc: 0.7680 - val_loss: 0.5866 - val_acc: 0.8469
# Epoch 3/20
# 272/272 [==============================] - 26s 96ms/step - loss: 0.4915 - acc: 0.8891 - val_loss: 0.3977 - val_acc: 0.8900
# Epoch 4/20
# 272/272 [==============================] - 27s 98ms/step - loss: 0.3137 - acc: 0.9307 - val_loss: 0.2762 - val_acc: 0.9270
# Epoch 5/20
# 272/272 [==============================] - 26s 95ms/step - loss: 0.2311 - acc: 0.9496 - val_loss: 0.2494 - val_acc: 0.9234
# Epoch 6/20
# 272/272 [==============================] - 26s 96ms/step - loss: 0.1831 - acc: 0.9580 - val_loss: 0.1961 - val_acc: 0.9454
# Epoch 7/20
# 272/272 [==============================] - 26s 96ms/step - loss: 0.1538 - acc: 0.9649 - val_loss: 0.1832 - val_acc: 0.9481
# Epoch 8/20
# 272/272 [==============================] - 29s 107ms/step - loss: 0.1305 - acc: 0.9702 - val_loss: 0.1754 - val_acc: 0.9474
# Epoch 9/20
# 272/272 [==============================] - 26s 94ms/step - loss: 0.1101 - acc: 0.9747 - val_loss: 0.1678 - val_acc: 0.9524
# Epoch 10/20
# 272/272 [==============================] - 28s 102ms/step - loss: 0.1095 - acc: 0.9725 - val_loss: 0.1683 - val_acc: 0.9540
# Epoch 11/20
# 272/272 [==============================] - 28s 103ms/step - loss: 0.0960 - acc: 0.9765 - val_loss: 0.1751 - val_acc: 0.9465
# Epoch 12/20
# 272/272 [==============================] - 26s 94ms/step - loss: 0.0922 - acc: 0.9761 - val_loss: 0.1407 - val_acc: 0.9594
# Epoch 13/20
# 272/272 [==============================] - 27s 98ms/step - loss: 0.0846 - acc: 0.9784 - val_loss: 0.1545 - val_acc: 0.9560
# Epoch 14/20
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0884 - acc: 0.9769 - val_loss: 0.1639 - val_acc: 0.9522
# Epoch 15/20
# 272/272 [==============================] - 26s 95ms/step - loss: 0.0772 - acc: 0.9790 - val_loss: 0.1460 - val_acc: 0.9592
# Epoch 16/20
# 272/272 [==============================] - 26s 96ms/step - loss: 0.0835 - acc: 0.9762 - val_loss: 0.1611 - val_acc: 0.9556
# Epoch 17/20
# 272/272 [==============================] - 27s 99ms/step - loss: 0.0766 - acc: 0.9788 - val_loss: 0.1448 - val_acc: 0.9601
# Epoch 18/20
# 272/272 [==============================] - 27s 98ms/step - loss: 0.0777 - acc: 0.9774 - val_loss: 0.1677 - val_acc: 0.9531
# Epoch 19/20
# 272/272 [==============================] - 27s 98ms/step - loss: 0.0703 - acc: 0.9805 - val_loss: 0.1401 - val_acc: 0.9585
# Epoch 20/20
# 272/272 [==============================] - 28s 102ms/step - loss: 0.0687 - acc: 0.9813 - val_loss: 0.1584 - val_acc: 0.9560
# Visualize training loss and accuracy change
# dict_keys(['val_acc', 'acc', 'loss', 'val_loss'])

# %%
print("Step 4: Test on new testing images from outside the dataset")
traffic_sign_pipeline.test(test_data_dir, test_labels)
# Out:
# Step 4: Test on new testing images from outside the dataset
# visualization for testing
# visualize before data augmentation on testing data
# visualize after data augmentation on testing data
# Top 5 probability for image id =  0
# class: 13, prob:0.9999405145645142
# class: 12, prob:1.718687781249173e-05
# class: 9, prob:1.603789314685855e-05
# class: 3, prob:9.971648978535086e-06
# class: 15, prob:3.0893202165316325e-06
# Top 5 probability for image id =  1
# class: 2, prob:0.9758037328720093
# class: 3, prob:0.014370091259479523
# class: 31, prob:0.0037103050854057074
# class: 5, prob:0.003370311576873064
# class: 38, prob:0.001201087492518127
# Top 5 probability for image id =  2
# class: 14, prob:0.8745701313018799
# class: 1, prob:0.07359214872121811
# class: 13, prob:0.017276939004659653
# class: 3, prob:0.01177813671529293
# class: 31, prob:0.010338550433516502
# Top 5 probability for image id =  3
# class: 18, prob:0.9917368292808533
# class: 11, prob:0.0022490322589874268
# class: 21, prob:0.0017676062416285276
# class: 26, prob:0.0007731837686151266
# class: 27, prob:0.0007455275626853108
# Top 5 probability for image id =  4
# class: 17, prob:0.9999456405639648
# class: 14, prob:3.0643022910226136e-05
# class: 33, prob:3.409176542845671e-06
# class: 13, prob:3.2737550554884365e-06
# class: 12, prob:2.604460632937844e-06
# Ground truth:  [13  3 14 27 40]
# Predicted labels [13  2 14 18 17]
# Accuracy on testing images = 0.4

# %%
print("Step 5: Test on German Traffic Sign testing dataset")
traffic_sign_pipeline.test_dataset()
# Out:
# Step 5: Test on German Traffic Sign testing dataset
# evaluated using the following metric:  ['loss', 'acc']
# test loss: 0.23297397540093223, test accuracy: 0.9388756929365114
